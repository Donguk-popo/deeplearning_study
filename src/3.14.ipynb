# %% [markdown]
# #### Frame Rate : 30FPS
# #### people, face_keypoints_2d, pose_keypoints_2d, hand_left_keypoints_2d, hand_right_keypoints_2d, face_keypoints_3d, pose_keypoints_3d, hand_left_keypoints_3d, hand_right_keypoints_3d, camparam
# #### 데이터는 각 키포인트 좌표와 신뢰도를 담고 있다
